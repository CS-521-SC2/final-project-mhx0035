# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report, precision_score, recall_score
from sklearn.model_selection import KFold
from sklearn import metrics

# %%
dataframe = pd.read_csv('downloaded_fake_news.csv')

# %%
dataframe
# Out:
#                                                   title  \
# 0                          You Can Smell Hillary’s Fear
# 1     Watch The Exact Moment Paul Ryan Committed Pol...
# 2           Kerry to go to Paris in gesture of sympathy
# 3     Bernie supporters on Twitter erupt in anger ag...
# 4      The Battle of New York: Why This Primary Matters
# ...                                                 ...
# 6330  State Department says it can't find emails fro...
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333  In Ethiopia, Obama seeks progress on peace, se...
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4     It's primary day in New York and front-runners...  REAL
# ...                                                 ...   ...
# 6330  The State Department told the Republican Natio...  REAL
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE
# 6332  Anti-Trump Protesters Are Tools of the Oligarc...  FAKE
# 6333  ADDIS ABABA, Ethiopia —President Obama convene...  REAL
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL
#
# [6335 rows x 3 columns]

# %%
vectorizer = TfidfVectorizer()

# %%
features = vectorizer.fit_transform(dataframe['title'])
labels = dataframe['label']

# %%
kf = KFold(n_splits=5)

# %% [markdown]
# # SVM

# %%
for train, test in kf.split(features):
    model = SVC()
    model.fit(features[train], labels.iloc[train])
    predicts = model.predict(features[test])
    #print('predictions',predicts)
    #print(labels[test])
    print(classification_report(labels[test], predicts))
# Out:
#               precision    recall  f1-score   support
#
#         FAKE       0.81      0.88      0.85       634
#         REAL       0.87      0.79      0.83       633
#
#     accuracy                           0.84      1267
#    macro avg       0.84      0.84      0.84      1267
# weighted avg       0.84      0.84      0.84      1267
#
#               precision    recall  f1-score   support
#
#         FAKE       0.81      0.86      0.83       663
#         REAL       0.84      0.77      0.80       604
#
#     accuracy                           0.82      1267
#    macro avg       0.82      0.82      0.82      1267
# weighted avg       0.82      0.82      0.82      1267
#
#               precision    recall  f1-score   support
#
#         FAKE       0.78      0.87      0.82       595
#         REAL       0.87      0.79      0.83       672
#
#     accuracy                           0.83      1267
#    macro avg       0.83      0.83      0.83      1267
# weighted avg       0.83      0.83      0.83      1267
#
#               precision    recall  f1-score   support
#
#         FAKE       0.80      0.86      0.83       628
#         REAL       0.85      0.79      0.82       639
#
#     accuracy                           0.82      1267
#    macro avg       0.83      0.82      0.82      1267
# weighted avg       0.83      0.82      0.82      1267
#
#               precision    recall  f1-score   support
#
#         FAKE       0.80      0.86      0.83       644
#         REAL       0.84      0.78      0.81       623
#
#     accuracy                           0.82      1267
#    macro avg       0.82      0.82      0.82      1267
# weighted avg       0.82      0.82      0.82      1267

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

for train, test in kf.split(features):
    model = LogisticRegression()
    model.fit(features[train], labels.iloc[train])
    # make predictions
    expected = labels[test]
    predicted = model.predict(features[test])
    print(classification_report(expected, predicted))
    print(metrics.recall_score(expected,predicted, average = None))
# Out:
#               precision    recall  f1-score   support
#
#         FAKE       0.80      0.87      0.83       634
#         REAL       0.86      0.78      0.82       633
#
#     accuracy                           0.83      1267
#    macro avg       0.83      0.83      0.83      1267
# weighted avg       0.83      0.83      0.83      1267
#
# [0.87066246 0.78199052]
#               precision    recall  f1-score   support
#
#         FAKE       0.80      0.85      0.82       663
#         REAL       0.82      0.76      0.79       604
#
#     accuracy                           0.81      1267
#    macro avg       0.81      0.81      0.81      1267
# weighted avg       0.81      0.81      0.81      1267
#
# [0.85067873 0.7615894 ]
#               precision    recall  f1-score   support
#
#         FAKE       0.77      0.86      0.81       595
#         REAL       0.86      0.78      0.82       672
#
#     accuracy                           0.82      1267
#    macro avg       0.82      0.82      0.82      1267
# weighted avg       0.82      0.82      0.82      1267
#
# [0.8605042  0.77678571]
#               precision    recall  f1-score   support
#
#         FAKE       0.81      0.84      0.83       628
#         REAL       0.84      0.81      0.82       639
#
#     accuracy                           0.83      1267
#    macro avg       0.83      0.83      0.83      1267
# weighted avg       0.83      0.83      0.83      1267
#
# [0.84394904 0.80907668]
#               precision    recall  f1-score   support
#
#         FAKE       0.79      0.84      0.81       644
#         REAL       0.82      0.78      0.80       623
#
#     accuracy                           0.81      1267
#    macro avg       0.81      0.81      0.81      1267
# weighted avg       0.81      0.81      0.81      1267
#
# [0.83695652 0.7752809 ]

# %% [markdown]
# # LinearSVC

# %%
from sklearn.svm import LinearSVC

for train, test in kf.split(features):
    model = LinearSVC()
    model.fit(features[train], labels.iloc[train])
    predicted = model.predict(features[test])
    #print('predictions',predicted)
    #print(labels[test])
    print(classification_report(labels[test], predicted))
    print(metrics.recall_score(expected,predicted, average = None))
# Out:
#               precision    recall  f1-score   support
#
#         FAKE       0.82      0.83      0.82       634
#         REAL       0.83      0.81      0.82       633
#
#     accuracy                           0.82      1267
#    macro avg       0.82      0.82      0.82      1267
# weighted avg       0.82      0.82      0.82      1267
#
# [0.51242236 0.48796148]
#               precision    recall  f1-score   support
#
#         FAKE       0.80      0.79      0.80       663
#         REAL       0.78      0.78      0.78       604
#
#     accuracy                           0.79      1267
#    macro avg       0.79      0.79      0.79      1267
# weighted avg       0.79      0.79      0.79      1267
#
# [0.52018634 0.48314607]
#               precision    recall  f1-score   support
#
#         FAKE       0.79      0.83      0.81       595
#         REAL       0.84      0.81      0.82       672
#
#     accuracy                           0.82      1267
#    macro avg       0.82      0.82      0.82      1267
# weighted avg       0.82      0.82      0.82      1267
#
# [0.48291925 0.50080257]
#               precision    recall  f1-score   support
#
#         FAKE       0.82      0.81      0.81       628
#         REAL       0.82      0.82      0.82       639
#
#     accuracy                           0.82      1267
#    macro avg       0.82      0.82      0.82      1267
# weighted avg       0.82      0.82      0.82      1267
#
# [0.50465839 0.51845907]
#               precision    recall  f1-score   support
#
#         FAKE       0.81      0.85      0.83       644
#         REAL       0.83      0.79      0.81       623
#
#     accuracy                           0.82      1267
#    macro avg       0.82      0.82      0.82      1267
# weighted avg       0.82      0.82      0.82      1267
#
# [0.84782609 0.79454254]

# %% [markdown]
# # MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB
# Multinomial Naive Bayes Classifier  

for train, test in kf.split(features):
    model = MultinomialNB(alpha=1)  
    model.fit(features[train], labels.iloc[train])  
    predicted = model.predict(features[test])
    #print('predictions',predicted)
    #print(labels[test])
    print(classification_report(labels[test], predicted))
    print(metrics.recall_score(expected,predicted, average = None))
# Out:
#               precision    recall  f1-score   support
#
#         FAKE       0.87      0.78      0.82       634
#         REAL       0.80      0.88      0.84       633
#
#     accuracy                           0.83      1267
#    macro avg       0.84      0.83      0.83      1267
# weighted avg       0.84      0.83      0.83      1267
#
# [0.45652174 0.55377207]
#               precision    recall  f1-score   support
#
#         FAKE       0.87      0.73      0.79       663
#         REAL       0.75      0.88      0.81       604
#
#     accuracy                           0.80      1267
#    macro avg       0.81      0.80      0.80      1267
# weighted avg       0.81      0.80      0.80      1267
#
# [0.42080745 0.54093098]
#               precision    recall  f1-score   support
#
#         FAKE       0.83      0.77      0.80       595
#         REAL       0.81      0.86      0.83       672
#
#     accuracy                           0.82      1267
#    macro avg       0.82      0.82      0.82      1267
# weighted avg       0.82      0.82      0.82      1267
#
# [0.41925466 0.54574639]
#               precision    recall  f1-score   support
#
#         FAKE       0.85      0.74      0.79       628
#         REAL       0.77      0.87      0.82       639
#
#     accuracy                           0.81      1267
#    macro avg       0.81      0.81      0.80      1267
# weighted avg       0.81      0.81      0.80      1267
#
# [0.4363354  0.57142857]
#               precision    recall  f1-score   support
#
#         FAKE       0.85      0.75      0.80       644
#         REAL       0.77      0.86      0.81       623
#
#     accuracy                           0.81      1267
#    macro avg       0.81      0.81      0.81      1267
# weighted avg       0.81      0.81      0.81      1267
#
# [0.75310559 0.86195827]

# %%
features
labels2 = dataframe['title']

# %% [markdown]
# # LinearSVC for article title test

# %%
for train, test in kf.split(features):
    model = LinearSVC()
    model.fit(features[train], labels2.iloc[train])
    predicted = model.predict(features[test])
    print('predictions',predicted)
    print(labels2[test])
# Out:
# predictions ["Can Huckabee Overcome The 'New Car Smell' Of Other Candidates?"
#  'Ashutosh attempts suicide at protest rally, rescued while proofreading suicide note'
#  'Kerry: Assad Must Go' ...
#  'Ashutosh attempts suicide at protest rally, rescued while proofreading suicide note'
#  'Obama Will Not Meet with Netanyahu During Trip to Washington'
#  'Trump accuses Obama, Hillary Clinton of founding Daesh']
# 0                            You Can Smell Hillary’s Fear
# 1       Watch The Exact Moment Paul Ryan Committed Pol...
# 2             Kerry to go to Paris in gesture of sympathy
# 3       Bernie supporters on Twitter erupt in anger ag...
# 4        The Battle of New York: Why This Primary Matters
#                               ...
# 1262    Scalia, Thomas & Alito have totally lost it: T...
# 1263                  ISIS: Mortal Threat Or Paper Tiger?
# 1264    Someone left a funny note asking the postman t...
# 1265    In rare foreign trip, Assad flies to Moscow to...
# 1266    Former ‘Apprentice’ contestant accuses Trump o...
# Name: title, Length: 1267, dtype: object
# predictions ['Speaker at Sanders Rally Tells Crowd Not to Vote Clinton, Gets Dragged Off Stage'
#  "Trump Expected to Name Running Mate Soon: Looking for an 'Attack Dog'"
#  'John Kasich wooing Iowans mostly from New Hampshire' ...
#  "For Trump, turning this around won't be easy"
#  'Will China Trigger the Next Global Recession?'
#  'The Modern History of \x91Rigged\x92 US Elections']
# 1267            Hispanic Crowd Boos Marco Rubio off Stage
# 1268    High Court Judges looking for a Truss to suppo...
# 1269    Trump's lean campaign machine relying mostly o...
# 1270    P. Parenthood Chief Goes Toe-to-Toe with Attac...
# 1271    New Poll: Americans Feel Less Safe After 15 Ye...
#                               ...
# 2529    Sex workers reject ‘biased’ BBC prostitution d...
# 2530    Comment on You Are What You Read: Research Rev...
# 2531    How Wisconsin could be a turning point in the ...
# 2532    The next recession could be around the corner,...
# 2533           The Modern History of ‘Rigged’ US Election
# Name: title, Length: 1267, dtype: object
# predictions ['RNC Chair urges against changing convention rules before Cleveland'
#  "'There's No Case Here.' Clinton Defiant amid Email Probe"
#  'Trump Campaign Bombs in Virginia, Again' ...
#  "Jeb Bush Is Suddenly Attacking Trump. Here's Why That Matters"
#  'As gas prices drops, states under increased pressure to hike taxes to replenish transportation funds'
#  'Clinton’s Iowa dilemma']
# 2534    The Cleveland Show: Convention starts under se...
# 2535    Senior Clinton aide maintained top secret clea...
# 2536    Hillary Clinton’s $500,000 Bribe to the FBI Ca...
# 2537    Cop Fired After Shooting Own 11-year-old Daugh...
# 2538    How Trump is following in Sanders's fundraisin...
#                               ...
# 3796    Creating an Anti-Muslim Bias at a Canadian Uni...
# 3797            Cruz Raises $20 Million In Fourth Quarter
# 3798    Judith Miller: It’s what was left unsaid in Tr...
# 3799    States look at hiking gas tax as fuel prices p...
# 3800    For some Republicans, Trump presents moral dil...
# Name: title, Length: 1267, dtype: object
# predictions ['Donald Trump and the $12.7 million Ukraine connection'
#  'Tennessee Children with Brittle Bones Suffer in State Care as Mom Charged with SBS'
#  'I watched Megyn Kelly for six weeks: How I learned to uncode the Fox News propaganda machine'
#  ... 'Did Gary Johnson Just Get Boxed Out of the Debates?'
#  'Trump Family Say Trump Brand Has NOT Been Damaged'
#  'Rand Paul: I won the debate last night']
# 3801    Obamacare Enrollments Hit Nearly 12 Million, T...
# 3802    The Powerful Act Immoral as they Also Suffer f...
# 3803    Megyn Kelly is an evil genius: How the Fox New...
# 3804    How Congress is giving new life (and scope) to...
# 3805    Obama Secures Enough Support For Iran Deal In ...
#                               ...
# 5063    Someone Just Donated $2.5 Million to Bail Out ...
# 5064    What Does Washington ‘Plan B’ in Syria Really ...
# 5065    McConnell, after his no-shutdowns pledge, quic...
# 5066    Russell Brand’s Back on ‘The Trews’ and He’s G...
# 5067      UFO over the East Valley here in AZ last night.
# Name: title, Length: 1267, dtype: object
# predictions ['Khodorkovsky: Putin is not going to cozy up to Washington'
#  '5 facts about consistent conservatives'
#  'Michelle Obama Deletes Hillary Clinton From Twitter' ...
#  'The Anti-Trump Protesters Are Tools of the Oligarchy'
#  'Obama: ‘Africa is on the move’'
#  'The press, feeling the Bern, suddenly weighs whether Sanders could derail Hillary']
# 5068          Putin: Russia Is Not Going To Attack Anyone
# 5069           How to Tell Debt Facts From Political Hype
# 5070           Trump on Twitter: Hillary is 'Brainwashed'
# 5071      Poll: Most disapprove of Obama handling of ISIS
# 5072                     The Trump – Epstein Rape Lawsuit
#                               ...
# 6330    State Department says it can't find emails fro...
# 6331    The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332    Anti-Trump Protesters Are Tools of the Oligarc...
# 6333    In Ethiopia, Obama seeks progress on peace, se...
# 6334    Jeb Bush Is Suddenly Attacking Trump. Here's W...
# Name: title, Length: 1267, dtype: object
